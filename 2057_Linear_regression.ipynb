# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("Student_Performance.csv")
df
# Out:
#     Attendance  Tutorial  Lab
# 0           70        10   42
# 1           92         7   39
# 2           67         3   32
# 3           82        16   50
# 4           80         9   44
# ..         ...       ...  ...
# 68          80        10   47
# 69          78         8   40
# 70          92         9   49
# 71          78        11   53
# 72          78        12   58
#
# [73 rows x 3 columns]

# %%
plt.xlabel('Attendance in Tutorial')
plt.ylabel('Attendance in Lab')
plt.scatter(df.Tutorial,df.Lab,marker='*',color = 'green')

# %%
lr=linear_model.LinearRegression()

# %%
lr.fit(df[['Tutorial']],df.Attendance)
# Out:
# LinearRegression()

# %%
lr.predict([[70]])
# Out:
# array([66.49081967])

# %%
lr.predict([[57]])
# Out:
# array([69.77385246])

# %%
lr.intercept_
# Out:
# 84.16868852459015

# %%
lr.coef_
# Out:
# array([-0.25254098])

# %%
plt.plot(df.Tutorial)

# %%
plt.plot(df.Lab)

# %%
plt.plot(df.Attendance)
